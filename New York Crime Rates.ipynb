# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('LocalCrimeJurisbyJuris.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
# Year                                         30 non-null int64
# Months                                       30 non-null int64
# Population                                   30 non-null int64
# Violent Crime rate                           30 non-null float64
# Murder and nonnegligent manslaughter rate    30 non-null float64
# Legacy rape rate /1                          29 non-null float64
# Revised rape rate /2                         1 non-null float64
# Robbery rate                                 30 non-null float64
# Aggravated assault rate                      30 non-null float64
# Unnamed: 9                                   0 non-null float64
# dtypes: float64(7), int64(3)
# memory usage: 2.4 KB
# None

# %%
plt.figure(figsize=(12, 8))

# %%
ax = plt.subplot(1,1,1)
ax.plot(df['Year'], df['Murder and nonnegligent manslaughter rate'], color='green')

# %%
ax2 = plt.subplot(1,1,1)
ax2.plot(df['Year'], df['Robbery rate'], color='green')
plt.show()
plt.savefig('foo.png')

# %%
ax3 = plt.subplot(1,1,1)
ax3.plot(df['Year'], df['Aggravated assault rate'], color='green')
plt.show()
plt.savefig('foo.png')
